# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("/content/lung_cancer_examples - lung_cancer_examples (1).csv")
df.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
df.columns
# Out:
# Index(['Name', 'Surname', 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'], dtype='object')

# %%
df.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %%
#Relationship with Age and Result based on people with Smoke Habbit
sns.lineplot(x='Age',y='Result',hue='Smokes',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Result'>

# %%
#Relationship with Age and Result based on people with Alkhol Habbit
sns.lineplot(x='Age',y='Result',hue='Alkhol',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Result'>

# %%
#Relationship between 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'
sns.pairplot(data=df)

# %%
#Relationship between Age and Alkhol
plt.figure(figsize=(50, 10))
g=sns.barplot(x='Age',y='Alkhol',data=df,color='skyblue')

# %%
#Relationship between Age and Smokes habbit
plt.figure(figsize=(50, 10))
g=sns.barplot(x='Age',y='Smokes',data=df,color="black")

# %%
sns.distplot(df.Result)
# Out:
# <ipython-input-25-265152acfc7e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Result)
# <Axes: xlabel='Result', ylabel='Density'>

# %%
#df1 is the filtered data with Result '1' who are with cancer
df1 = df[df.Result==1]

# %%
#Distribution of Age with Cancer positive result
sns.distplot(df1.Age)
# Out:
# <ipython-input-27-1b097bd047fe>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1.Age)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **People who are aged around 60years are prone to test positive**

# %%
#people with no cancer
df2 = df[df.Result==0]

# %%
sns.distplot(df2.Age)
# Out:
# <ipython-input-29-965ceeaa3d02>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2.Age)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# People around the range 30-40 have less chance of cancer

# %%
#Distribution of Age with Cancer positive result who consumes Alkhol
sns.distplot(df1.Alkhol)
# Out:
# <ipython-input-30-790c768843ec>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1.Alkhol)
# <Axes: xlabel='Alkhol', ylabel='Density'>

# %%
sns.scatterplot(x="Age", y="Result", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Result'>

# %%
sns.scatterplot(x="Age", y="Result",hue="Smokes",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Result'>

# %%
sns.heatmap(data=df[['Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result']],cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(50, 20))
sns.violinplot(x='Age',y='Result',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Result'>
